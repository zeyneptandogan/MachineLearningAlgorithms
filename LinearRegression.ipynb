# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split 

from sklearn import metrics
# %matplotlib inline

# %%
df = pd.read_excel('Data_Pure.xlsx')
df.head()
# Out:
#    Input 1  Input 2  Input 3  Input 4  Input 5  Input 6  Output
# 0      807      317      163      178       80       65   0.112
# 1      875      346      164      173       79       60   0.420
# 2      837      331      173      188       87       69   0.687
# 3      710      293      167      184       87       70   0.869
# 4      646      270      169      191       93       76   0.952

# %%
features=['Input 1', 'Input 2', 'Input 3', 'Input 4', 'Input 5', 'Input 6']
X = df[['Input 1', 'Input 2', 'Input 3', 'Input 4', 'Input 5', 'Input 6']].values
y= df['Output'].values

# %%
# train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# let's have a look at the coefficients, 
# i.e m values
from sklearn.linear_model import LinearRegression
model = LinearRegression()  
model.fit(X_train, y_train)
coeff_df = pd.DataFrame(model.coef_, features, columns=['Coefficient'])  
coeff_df
# Out:
#          Coefficient
# Input 1     0.000332
# Input 2     0.010713
# Input 3    -0.033904
# Input 4    -0.054623
# Input 5     0.100408
# Input 6     0.058532

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("mse: {}".format(mse))
print("mae: {}".format(mae))
print("rmse: {}".format(rmse))
# Out:
# mse: 0.027226053521611993
# mae: 0.13128507658900113
# rmse: 0.1650031924588491
